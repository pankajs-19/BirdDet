# %% [markdown]
# # 0. Setup Paths

# %%
import os

# %%
CUSTOM_MODEL_NAME = 'my_ssd_mobnet_v9.2' 
PRETRAINED_MODEL_NAME = 'ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8'
PRETRAINED_MODEL_URL = 'http://download.tensorflow.org/models/object_detection/tf2/20200711/ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8.tar.gz'
TF_RECORD_SCRIPT_NAME = 'generate_tfrecord.py'
LABEL_MAP_NAME = 'label_map.pbtxt'

# %%
paths = {
    'WORKSPACE_PATH': os.path.join('Tensorflow', 'workspace'),
    'SCRIPTS_PATH': os.path.join('Tensorflow','scripts'),
    'APIMODEL_PATH': os.path.join('Tensorflow','models'),
    'ANNOTATION_PATH': os.path.join('Tensorflow', 'workspace','annotations'),
    'IMAGE_PATH': 
    os.path.join('Tensorflow', 'workspace','images'),
    'MODEL_PATH': os.path.join('Tensorflow', 'workspace','models'),
    'PRETRAINED_MODEL_PATH': os.path.join('Tensorflow', 'workspace','pre-trained-models'),
    'CHECKPOINT_PATH': os.path.join('Tensorflow', 'workspace','models',CUSTOM_MODEL_NAME), 
    'OUTPUT_PATH': os.path.join('Tensorflow', 'workspace','models',CUSTOM_MODEL_NAME, 'export'), 
    'TFJS_PATH':os.path.join('Tensorflow', 'workspace','models',CUSTOM_MODEL_NAME, 'tfjsexport'), 
    'TFLITE_PATH':os.path.join('Tensorflow', 'workspace','models',CUSTOM_MODEL_NAME, 'tfliteexport'), 
    'PROTOC_PATH':os.path.join('Tensorflow','protoc')
 }

# %%
files = {
    'PIPELINE_CONFIG':os.path.join('Tensorflow', 'workspace','models', CUSTOM_MODEL_NAME, 'pipeline.config'),
    'TF_RECORD_SCRIPT': os.path.join(paths['SCRIPTS_PATH'], TF_RECORD_SCRIPT_NAME), 
    'LABELMAP': os.path.join(paths['ANNOTATION_PATH'], LABEL_MAP_NAME)
}

# %%
files
# Out:
# {'PIPELINE_CONFIG': 'Tensorflow/workspace/models/my_ssd_mobnet_v9.2/pipeline.config',
#  'TF_RECORD_SCRIPT': 'Tensorflow/scripts/generate_tfrecord.py',
#  'LABELMAP': 'Tensorflow/workspace/annotations/label_map.pbtxt'}

# %%
for path in paths.values():
    if not os.path.exists(path):
        if os.name == 'posix':
            # !mkdir -p {path}
        if os.name == 'nt':
            # !mkdir {path}

# %% [markdown]
# # 1. Download TF Models Pretrained Models from Tensorflow Model Zoo and Install TFOD

# %%
# https://www.tensorflow.org/install/source_windows

# %%
if os.name=='nt':
    # !pip install wget
    import wget

# %%
if not os.path.exists(os.path.join(paths['APIMODEL_PATH'], 'research', 'object_detection')):
    # !git clone https://github.com/tensorflow/models {paths['APIMODEL_PATH']}

# %%
# Install Tensorflow Object Detection 
if os.name=='posix':  
    # !sudo -S apt-get install protobuf-compiler </home/pankajs19/Documents/birdet/TFODCourse/pass.txt
    # !cd Tensorflow/models/research && protoc object_detection/protos/*.proto --python_out=. && cp object_detection/packages/tf2/setup.py . && python -m pip install . 
        
    
if os.name=='nt':
    url="https://github.com/protocolbuffers/protobuf/releases/download/v3.15.6/protoc-3.15.6-win64.zip"
    wget.download(url)
    # !move protoc-3.15.6-win64.zip {paths['PROTOC_PATH']}
    # !cd {paths['PROTOC_PATH']} && tar -xf protoc-3.15.6-win64.zip
    os.environ['PATH'] += os.pathsep + os.path.abspath(os.path.join(paths['PROTOC_PATH'], 'bin'))   
    # !cd Tensorflow/models/research && protoc object_detection/protos/*.proto --python_out=. && copy object_detection\\packages\\tf2\\setup.py setup.py && python setup.py build && python setup.py install
    # !cd Tensorflow/models/research/slim && pip install -e .
# Out:
# Reading package lists... Done:
# Building dependency tree... Done
# Reading state information... Done
# protobuf-compiler is already the newest version (3.12.4-1ubuntu7.22.04.1).
# 0 upgraded, 0 newly installed, 0 to remove and 216 not upgraded.
# 8 not fully installed or removed.
# After this operation, 0 B of additional disk space will be used.
# Do you want to continue? [Y/n] Setting up nvidia-dkms-535 (535.54.03-0ubuntu1) ...
# update-initramfs: deferring update (trigger activated)
#
# A modprobe blacklist file has been created at /etc/modprobe.d to prevent Nouveau
# from loading. This can be reverted by deleting the following file:
# /etc/modprobe.d/nvidia-graphics-drivers.conf
#
# A new initrd image has also been created. To revert, please regenerate your
# initrd by running the following command after deleting the modprobe.d file:
# `/usr/sbin/initramfs -u`
#
# *****************************************************************************
# *** Reboot your computer and verify that the NVIDIA graphics driver can   ***
# *** be loaded.                                                            ***
# *****************************************************************************
#
# INFO:Enable nvidia
# DEBUG:Parsing /usr/share/ubuntu-drivers-common/quirks/dell_latitude
# DEBUG:Parsing /usr/share/ubuntu-drivers-common/quirks/lenovo_thinkpad
# DEBUG:Parsing /usr/share/ubuntu-drivers-common/quirks/put_your_quirks_here
# Removing old nvidia-535.54.03 DKMS files...
# Deleting module nvidia-535.54.03 completely from the DKMS tree.
# Loading new nvidia-535.54.03 DKMS files...
# Building for 6.5.0-21-generic
# Building for architecture x86_64
# Building initial module for 6.5.0-21-generic
# ERROR: Cannot create report: [Errno 17] File exists: '/var/crash/nvidia-kernel-source-535.0.crash'
# Error! Bad return status for module build on kernel: 6.5.0-21-generic (x86_64)
# Consult /var/lib/dkms/nvidia/535.54.03/build/make.log for more information.
# dpkg: error processing package nvidia-dkms-535 (--configure):
#  installed nvidia-dkms-535 package post-installation script subprocess returned error exit status 10
# dpkg: dependency problems prevent configuration of cuda-drivers-535:
#  cuda-drivers-535 depends on nvidia-dkms-535 (>= 535.54.03); however:
#   Package nvidia-dkms-535 is not configured yet.
#
# dpkg: error processing package cuda-drivers-535 (--configure):
#  dependency problems - leaving unconfigured
# dpkg: dependency problems prevent configuration of cuda-drivers:
#  cuda-drivers depends on cuda-drivers-535 (= 535.54.03-1); however:
#   Package cuda-drivers-535 is not configured yet.
#
# dpkg: error processing package cuda-drivers (--configure):
#  dependency problems - leaving unconfigured
# No apport report written because the error message indicates its a followup error from a previous failure.
# No apport report written because the error message indicates its a followup error from a previous failure.
# No apport report written because MaxReports is reached already
# No apport report written because MaxReports is reached already
# dpkg: dependency problems prevent configuration of nvidia-driver-535:
#  nvidia-driver-535 depends on nvidia-dkms-535 (= 535.54.03-0ubuntu1); however:
#   Package nvidia-dkms-535 is not configured yet.
#
# dpkg: error processing package nvidia-driver-535 (--configure):
#  dependency problems - leaving unconfigured
# dpkg: dependency problems prevent configuration of cuda-runtime-12-2:
#  cuda-runtime-12-2 depends on cuda-drivers (>= 535.54.03); however:
#   Package cuda-drivers is not configured yet.
#
# dpkg: error processing package cuda-runtime-12-2 (--configure):
#  dependency problems - leaving unconfigured
# dpkg: dependency problems prevent configuration of cuda-12-2:
#  cuda-12-2 depends on cuda-runtime-12-2 (>= 12.2.0); however:
#   Package cuda-runtime-12-2 is not configured yet.
#
# dpkg: error processing package cuda-12-2 (--configure):
#  dependency problems - leaving unconfigured
# dpkg: dependency problems prevent configuration of cuda:
#  cuda depends on cuda-12-2 (>= 12.2.0); however:
#   Package cuda-12-2 isNo apport report written because MaxReports is reached already
# No apport report written because MaxReports is reached already
# No apport report written because MaxReports is reached already
#  not configured yet.
#
# dpkg: error processing package cuda (--configure):
#  dependency problems - leaving unconfigured
# dpkg: dependency problems prevent configuration of cuda-demo-suite-12-2:
#  cuda-demo-suite-12-2 depends on cuda-runtime-12-2; however:
#   Package cuda-runtime-12-2 is not configured yet.
#
# dpkg: error processing package cuda-demo-suite-12-2 (--configure):
#  dependency problems - leaving unconfigured
# Processing triggers for initramfs-tools (0.140ubuntu13.2) ...
# update-initramfs: Generating /boot/initrd.img-6.5.0-21-generic
# Errors were encountered while processing:
#  nvidia-dkms-535
#  cuda-drivers-535
#  cuda-drivers
#  nvidia-driver-535
#  cuda-runtime-12-2
#  cuda-12-2
#  cuda
#  cuda-demo-suite-12-2
# E: Sub-process /usr/bin/dpkg returned an error code (1)
# Processing /home/pankajs19/Documents/birdet/TFODCourse/Tensorflow/models/research
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: Cython in /home/pankajs19/Documents/birdet/TFODCourse/tfod/lib/python3.10/site-packages (from object-detection==0.1) (3.0.8)
# Requirement already satisfied: apache-beam in /home/pankajs19/Documents/birdet/TFODCourse/tfod/lib/python3.10/site-packages (from object-detection==0.1) (2.54.0)
# Requirement already satisfied: avro-python3 in /home/pankajs19/Documents/birdet/TFODCourse/tfod/lib/python3.10/site-packages (from object-detection==0.1) (1.10.2)
# Requirement already satisfied: contextlib2 in /home/pankajs19/Documents/birdet/TFODCourse/tfod/lib/python3.10/site-packages (from object-detection==0.1) (21.6.0)
# Requirement already satisfied: keras in /home/pankajs19/Documents/birdet/TFODCourse/tfod/lib/python3.10/site-packages (from object-detection==0.1) (3.0.5)
# Requirement already satisfied: lvis in /home/pankajs19/Documents/birdet/TFODCourse/tfod/lib/python3.10/site-packages (from object-detection==0.1) (0.5.3)
# Requirement already satisfied: lxml in /home/pankajs19/Documents/birdet/TFODCourse/tfod/lib/python3.10/site-packages (from object-detection==0.1) (5.1.0)
# Requirement already satisfied: matplotlib in /home/pankajs19/Documents/birdet/TFODCourse/tfod/lib/python3.10/site-packages (from object-detection==0.1) (3.8.3)
# Requirement already satisfied: pandas in /home/pankajs19/Documents/birdet/TFODCourse/tfod/lib/python3.10/site-packages (from object-detection==0.1) (1.3.5)
# Requirement already satisfied: pillow in /home/pankajs19/Documents/birdet/TFODCourse/tfod/lib/python3.10/site-packages (from object-detection==0.1) (10.2.0)
# Requirement already satisfied: pycocotools in /home/pankajs19/Documents/birdet/TFODCourse/tfod/lib/python3.10/site-packages (from object-detection==0.1) (2.0.7)
# Requirement already satisfied: pyparsing==2.4.7 in /home/pankajs19/Documents/birdet/TFODCourse/tfod/lib/python3.10/site-packages (from object-detection==0.1) (2.4.7)
# Requirement already satisfied: sacrebleu<=2.2.0 in /home/pankajs19/Documents/birdet/TFODCourse/tfod/lib/python3.10/site-packages (from object-detection==0.1) (2.2.0)
# Requirement already satisfied: scipy in /home/pankajs19/Documents/birdet/TFODCourse/tfod/lib/python3.10/site-packages (from object-detection==0.1) (1.12.0)
# Requirement already satisfied: six in /home/pankajs19/Documents/birdet/TFODCourse/tfod/lib/python3.10/site-packages (from object-detection==0.1) (1.16.0)
# Requirement already satisfied: tensorflow_io in /home/pankajs19/Documents/birdet/TFODCourse/tfod/lib/python3.10/site-packages (from object-detection==0.1) (0.36.0)
# Requirement already satisfied: tf-models-official>=2.5.1 in /home/pankajs19/Documents/birdet/TFODCourse/tfod/lib/python3.10/site-packages (from object-detection==0.1) (2.15.0)
# Requirement already satisfied: tf-slim in /home/pankajs19/Documents/birdet/TFODCourse/tfod/lib/python3.10/site-packages (from object-detection==0.1) (1.1.0)
# Requirement already satisfied: portalocker in /home/pankajs19/Documents/birdet/TFODCourse/tfod/lib/python3.10/site-packages (from sacrebleu<=2.2.0->object-detection==0.1) (2.8.2)
# Requirement already satisfied: regex in /home/pankajs19/Documents/birdet/TFODCourse/tfod/lib/python3.10/site-packages (from sacrebleu<=2.2.0->object-detection==0.1) (2023.12.25)
# Requirement already satisfied: tabulate>=0.8.9 in /home/pankajs19/Documents/birdet/TFODCourse/tfod/lib/python3.10/site-packages (from sacrebleu<=2.2.0->object-detection==0.1) (0.9.0)
# Requirement already satisfied: numpy>=1.17 in /home/pankajs19/Documents/birdet/TFODCourse/tfod/lib/python3.10/site-packages (from sacrebleu<=2.2.0->object-detection==0.1) (1.24.3)
# Requirement already satisfied: colorama in /home/pankajs19/Documents/birdet/TFODCourse/tfod/lib/python3.10/site-packages (from sacrebleu<=2.2.0->object-detection==0.1) (0.4.6)
# Requirement already satisfied: gin-config in /home/pankajs19/Documents/birdet/TFODCourse/tfod/lib/python3.10/site-packages (from tf-models-official>=2.5.1->object-detection==0.1) (0.5.0)
# Requirement already satisfied: google-api-python-client>=1.6.7 in /home/pankajs19/Documents/birdet/TFODCourse/tfod/lib/python3.10/site-packages (from tf-models-official>=2.5.1->object-detection==0.1) (2.119.0)
# Requirement already satisfied: immutabledict in /home/pankajs19/Documents/birdet/TFODCourse/tfod/lib/python3.10/site-packages (from tf-models-official>=2.5.1->object-detection==0.1) (4.1.0)
# Requirement already satisfied: kaggle>=1.3.9 in /home/pankajs19/Documents/birdet/TFODCourse/tfod/lib/python3.10/site-packages (from tf-models-official>=2.5.1->object-detection==0.1) (1.6.6)
# Requirement already satisfied: oauth2client in /home/pankajs19/Documents/birdet/TFODCourse/tfod/lib/python3.10/site-packages (from tf-models-official>=2.5.1->object-detection==0.1) (4.1.3)
# Requirement already satisfied: opencv-python-headless in /home/pankajs19/Documents/birdet/TFODCourse/tfod/lib/python3.10/site-packages (from tf-models-official>=2.5.1->object-detection==0.1) (4.9.0.80)
# Requirement already satisfied: psutil>=5.4.3 in /home/pankajs19/Documents/birdet/TFODCourse/tfod/lib/python3.10/site-packages (from tf-models-official>=2.5.1->object-detection==0.1) (5.9.8)
# Requirement already satisfied: py-cpuinfo>=3.3.0 in /home/pankajs19/Documents/birdet/TFODCourse/tfod/lib/python3.10/site-packages (from tf-models-official>=2.5.1->object-detection==0.1) (9.0.0)
# Requirement already satisfied: pyyaml>=6.0.0 in /home/pankajs19/Documents/birdet/TFODCourse/tfod/lib/python3.10/site-packages (from tf-models-official>=2.5.1->object-detection==0.1) (6.0.1)
# Requirement already satisfied: sentencepiece in /home/pankajs19/Documents/birdet/TFODCourse/tfod/lib/python3.10/site-packages (from tf-models-official>=2.5.1->object-detection==0.1) (0.2.0)
# Requirement already satisfied: seqeval in /home/pankajs19/Documents/birdet/TFODCourse/tfod/lib/python3.10/site-packages (from tf-models-official>=2.5.1->object-detection==0.1) (1.2.2)
# Requirement already satisfied: tensorflow-datasets in /home/pankajs19/Documents/birdet/TFODCourse/tfod/lib/python3.10/site-packages (from tf-models-official>=2.5.1->object-detection==0.1) (4.9.4)
# Requirement already satisfied: tensorflow-hub>=0.6.0 in /home/pankajs19/Documents/birdet/TFODCourse/tfod/lib/python3.10/site-packages (from tf-models-official>=2.5.1->object-detection==0.1) (0.16.1)
# Requirement already satisfied: tensorflow-model-optimization>=0.4.1 in /home/pankajs19/Documents/birdet/TFODCourse/tfod/lib/python3.10/site-packages (from tf-models-official>=2.5.1->object-detection==0.1) (0.8.0)
# Requirement already satisfied: tensorflow-text~=2.15.0 in /home/pankajs19/Documents/birdet/TFODCourse/tfod/lib/python3.10/site-packages (from tf-models-official>=2.5.1->object-detection==0.1) (2.15.0)
# Collecting tensorflow~=2.15.0 (from tf-models-official>=2.5.1->object-detection==0.1)
#   Using cached tensorflow-2.15.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.2 kB)
# Requirement already satisfied: python-dateutil>=2.7.3 in /home/pankajs19/Documents/birdet/TFODCourse/tfod/lib/python3.10/site-packages (from pandas->object-detection==0.1) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /home/pankajs19/Documents/birdet/TFODCourse/tfod/lib/python3.10/site-packages (from pandas->object-detection==0.1) (2024.1)
# Requirement already satisfied: absl-py>=0.2.2 in /home/pankajs19/Documents/birdet/TFODCourse/tfod/lib/python3.10/site-packages (from tf-slim->object-detection==0.1) (1.4.0)
# Requirement already satisfied: crcmod<2.0,>=1.7 in /home/pankajs19/Documents/birdet/TFODCourse/tfod/lib/python3.10/site-packages (from apache-beam->object-detection==0.1) (1.7)
# Requirement already satisfied: orjson<4,>=3.9.7 in /home/pankajs19/Documents/birdet/TFODCourse/tfod/lib/python3.10/site-packages (from apache-beam->object-detection==0.1) (3.9.15)
# Requirement already satisfied: dill<0.3.2,>=0.3.1.1 in /home/pankajs19/Documents/birdet/TFODCourse/tfod/lib/python3.10/site-packages (from apache-beam->object-detection==0.1) (0.3.1.1)
# Requirement already satisfied: cloudpickle~=2.2.1 in /home/pankajs19/Documents/birdet/TFODCourse/tfod/lib/python3.10/site-packages (from apache-beam->object-detection==0.1) (2.2.1)
# Requirement already satisfied: fastavro<2,>=0.23.6 in /home/pankajs19/Documents/birdet/TFODCourse/tfod/lib/python3.10/site-packages (from apache-beam->object-detection==0.1) (1.9.4)
# Requirement already satisfied: fasteners<1.0,>=0.3 in /home/pankajs19/Documents/birdet/TFODCourse/tfod/lib/python3.10/site-packages (from apache-beam->object-detection==0.1) (0.19)
# Requirement already satisfied: grpcio!=1.48.0,<2,>=1.33.1 in /home/pankajs19/Documents/birdet/TFODCourse/tfod/lib/python3.10/site-packages (from apache-beam->object-detection==0.1) (1.62.0)
# Requirement already satisfied: hdfs<3.0.0,>=2.1.0 in /home/pankajs19/Documents/birdet/TFODCourse/tfod/lib/python3.10/site-packages (from apache-beam->object-detection==0.1) (2.7.3)
# Requirement already satisfied: httplib2<0.23.0,>=0.8 in /home/pankajs19/Documents/birdet/TFODCourse/tfod/lib/python3.10/site-packages (from apache-beam->object-detection==0.1) (0.22.0)
# Requirement already satisfied: js2py<1,>=0.74 in /home/pankajs19/Documents/birdet/TFODCourse/tfod/lib/python3.10/site-packages (from apache-beam->object-detection==0.1) (0.74)
# Requirement already satisfied: jsonschema<5.0.0,>=4.0.0 in /home/pankajs19/Documents/birdet/TFODCourse/tfod/lib/python3.10/site-packages (from apache-beam->object-detection==0.1) (4.21.1)
# Requirement already satisfied: jsonpickle<4.0.0,>=3.0.0 in /home/pankajs19/Documents/birdet/TFODCourse/tfod/lib/python3.10/site-packages (from apache-beam->object-detection==0.1) (3.0.3)
# Requirement already satisfied: objsize<0.8.0,>=0.6.1 in /home/pankajs19/Documents/birdet/TFODCourse/tfod/lib/python3.10/site-packages (from apache-beam->object-detection==0.1) (0.7.0)
# Requirement already satisfied: packaging>=22.0 in /home/pankajs19/Documents/birdet/TFODCourse/tfod/lib/python3.10/site-packages (from apache-beam->object-detection==0.1) (23.2)
# Requirement already satisfied: pymongo<5.0.0,>=3.8.0 in /home/pankajs19/Documents/birdet/TFODCourse/tfod/lib/python3.10/site-packages (from apache-beam->object-detection==0.1) (4.6.2)
# Requirement already satisfied: proto-plus<2,>=1.7.1 in /home/pankajs19/Documents/birdet/TFODCourse/tfod/lib/python3.10/site-packages (from apache-beam->object-detection==0.1) (1.23.0)
# Requirement already satisfied: protobuf!=4.0.*,!=4.21.*,!=4.22.0,!=4.23.*,!=4.24.*,<4.26.0,>=3.20.3 in /home/pankajs19/Documents/birdet/TFODCourse/tfod/lib/python3.10/site-packages (from apache-beam->object-detection==0.1) (3.20.3)
# Requirement already satisfied: pydot<2,>=1.2.0 in /home/pankajs19/Documents/birdet/TFODCourse/tfod/lib/python3.10/site-packages (from apache-beam->object-detection==0.1) (1.4.2)
# Requirement already satisfied: requests<3.0.0,>=2.24.0 in /home/pankajs19/Documents/birdet/TFODCourse/tfod/lib/python3.10/site-packages (from apache-beam->object-detection==0.1) (2.31.0)
# Requirement already satisfied: typing-extensions>=3.7.0 in /home/pankajs19/Documents/birdet/TFODCourse/tfod/lib/python3.10/site-packages (from apache-beam->object-detection==0.1) (4.5.0)
# Requirement already satisfied: zstandard<1,>=0.18.0 in /home/pankajs19/Documents/birdet/TFODCourse/tfod/lib/python3.10/site-packages (from apache-beam->object-detection==0.1) (0.22.0)
# Requirement already satisfied: pyarrow<15.0.0,>=3.0.0 in /home/pankajs19/Documents/birdet/TFODCourse/tfod/lib/python3.10/site-packages (from apache-beam->object-detection==0.1) (14.0.2)
# Requirement already satisfied: pyarrow-hotfix<1 in /home/pankajs19/Documents/birdet/TFODCourse/tfod/lib/python3.10/site-packages (from apache-beam->object-detection==0.1) (0.6)
# Requirement already satisfied: rich in /home/pankajs19/Documents/birdet/TFODCourse/tfod/lib/python3.10/site-packages (from keras->object-detection==0.1) (13.7.0)
# Requirement already satisfied: namex in /home/pankajs19/Documents/birdet/TFODCourse/tfod/lib/python3.10/site-packages (from keras->object-detection==0.1) (0.0.7)
# Requirement already satisfied: h5py in /home/pankajs19/Documents/birdet/TFODCourse/tfod/lib/python3.10/site-packages (from keras->object-detection==0.1) (3.10.0)
# Requirement already satisfied: dm-tree in /home/pankajs19/Documents/birdet/TFODCourse/tfod/lib/python3.10/site-packages (from keras->object-detection==0.1) (0.1.8)
# Requirement already satisfied: ml-dtypes in /home/pankajs19/Documents/birdet/TFODCourse/tfod/lib/python3.10/site-packages (from keras->object-detection==0.1) (0.3.2)
# Requirement already satisfied: cycler>=0.10.0 in /home/pankajs19/Documents/birdet/TFODCourse/tfod/lib/python3.10/site-packages (from lvis->object-detection==0.1) (0.12.1)
# Requirement already satisfied: kiwisolver>=1.1.0 in /home/pankajs19/Documents/birdet/TFODCourse/tfod/lib/python3.10/site-packages (from lvis->object-detection==0.1) (1.4.5)
# Requirement already satisfied: opencv-python>=4.1.0.25 in /home/pankajs19/Documents/birdet/TFODCourse/tfod/lib/python3.10/site-packages (from lvis->object-detection==0.1) (4.9.0.80)
# Requirement already satisfied: contourpy>=1.0.1 in /home/pankajs19/Documents/birdet/TFODCourse/tfod/lib/python3.10/site-packages (from matplotlib->object-detection==0.1) (1.2.0)
# Requirement already satisfied: fonttools>=4.22.0 in /home/pankajs19/Documents/birdet/TFODCourse/tfod/lib/python3.10/site-packages (from matplotlib->object-detection==0.1) (4.49.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem==0.36.0 in /home/pankajs19/Documents/birdet/TFODCourse/tfod/lib/python3.10/site-packages (from tensorflow_io->object-detection==0.1) (0.36.0)
# Requirement already satisfied: google-auth<3.0.0.dev0,>=1.19.0 in /home/pankajs19/Documents/birdet/TFODCourse/tfod/lib/python3.10/site-packages (from google-api-python-client>=1.6.7->tf-models-official>=2.5.1->object-detection==0.1) (2.28.1)
# Requirement already satisfied: google-auth-httplib2>=0.1.0 in /home/pankajs19/Documents/birdet/TFODCourse/tfod/lib/python3.10/site-packages (from google-api-python-client>=1.6.7->tf-models-official>=2.5.1->object-detection==0.1) (0.2.0)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5 in /home/pankajs19/Documents/birdet/TFODCourse/tfod/lib/python3.10/site-packages (from google-api-python-client>=1.6.7->tf-models-official>=2.5.1->object-detection==0.1) (2.17.1)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in /home/pankajs19/Documents/birdet/TFODCourse/tfod/lib/python3.10/site-packages (from google-api-python-client>=1.6.7->tf-models-official>=2.5.1->object-detection==0.1) (4.1.1)
# Requirement already satisfied: docopt in /home/pankajs19/Documents/birdet/TFODCourse/tfod/lib/python3.10/site-packages (from hdfs<3.0.0,>=2.1.0->apache-beam->object-detection==0.1) (0.6.2)
# Requirement already satisfied: tzlocal>=1.2 in /home/pankajs19/Documents/birdet/TFODCourse/tfod/lib/python3.10/site-packages (from js2py<1,>=0.74->apache-beam->object-detection==0.1) (5.2)
# Requirement already satisfied: pyjsparser>=2.5.1 in /home/pankajs19/Documents/birdet/TFODCourse/tfod/lib/python3.10/site-packages (from js2py<1,>=0.74->apache-beam->object-detection==0.1) (2.7.1)
# Requirement already satisfied: attrs>=22.2.0 in /home/pankajs19/Documents/birdet/TFODCourse/tfod/lib/python3.10/site-packages (from jsonschema<5.0.0,>=4.0.0->apache-beam->object-detection==0.1) (23.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /home/pankajs19/Documents/birdet/TFODCourse/tfod/lib/python3.10/site-packages (from jsonschema<5.0.0,>=4.0.0->apache-beam->object-detection==0.1) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in /home/pankajs19/Documents/birdet/TFODCourse/tfod/lib/python3.10/site-packages (from jsonschema<5.0.0,>=4.0.0->apache-beam->object-detection==0.1) (0.33.0)
# Requirement already satisfied: rpds-py>=0.7.1 in /home/pankajs19/Documents/birdet/TFODCourse/tfod/lib/python3.10/site-packages (from jsonschema<5.0.0,>=4.0.0->apache-beam->object-detection==0.1) (0.18.0)
# Requirement already satisfied: bleach in /home/pankajs19/Documents/birdet/TFODCourse/tfod/lib/python3.10/site-packages (from kaggle>=1.3.9->tf-models-official>=2.5.1->object-detection==0.1) (6.1.0)
# Requirement already satisfied: certifi in /home/pankajs19/Documents/birdet/TFODCourse/tfod/lib/python3.10/site-packages (from kaggle>=1.3.9->tf-models-official>=2.5.1->object-detection==0.1) (2024.2.2)
# Requirement already satisfied: python-slugify in /home/pankajs19/Documents/birdet/TFODCourse/tfod/lib/python3.10/site-packages (from kaggle>=1.3.9->tf-models-official>=2.5.1->object-detection==0.1) (8.0.4)
# Requirement already satisfied: tqdm in /home/pankajs19/Documents/birdet/TFODCourse/tfod/lib/python3.10/site-packages (from kaggle>=1.3.9->tf-models-official>=2.5.1->object-detection==0.1) (4.66.2)
# Requirement already satisfied: urllib3 in /home/pankajs19/Documents/birdet/TFODCourse/tfod/lib/python3.10/site-packages (from kaggle>=1.3.9->tf-models-official>=2.5.1->object-detection==0.1) (2.2.1)
# Requirement already satisfied: dnspython<3.0.0,>=1.16.0 in /home/pankajs19/Documents/birdet/TFODCourse/tfod/lib/python3.10/site-packages (from pymongo<5.0.0,>=3.8.0->apache-beam->object-detection==0.1) (2.6.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/pankajs19/Documents/birdet/TFODCourse/tfod/lib/python3.10/site-packages (from requests<3.0.0,>=2.24.0->apache-beam->object-detection==0.1) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/pankajs19/Documents/birdet/TFODCourse/tfod/lib/python3.10/site-packages (from requests<3.0.0,>=2.24.0->apache-beam->object-detection==0.1) (3.6)
# Requirement already satisfied: astunparse>=1.6.0 in /home/pankajs19/Documents/birdet/TFODCourse/tfod/lib/python3.10/site-packages (from tensorflow~=2.15.0->tf-models-official>=2.5.1->object-detection==0.1) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.5.26 in /home/pankajs19/Documents/birdet/TFODCourse/tfod/lib/python3.10/site-packages (from tensorflow~=2.15.0->tf-models-official>=2.5.1->object-detection==0.1) (23.5.26)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /home/pankajs19/Documents/birdet/TFODCourse/tfod/lib/python3.10/site-packages (from tensorflow~=2.15.0->tf-models-official>=2.5.1->object-detection==0.1) (0.4.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /home/pankajs19/Documents/birdet/TFODCourse/tfod/lib/python3.10/site-packages (from tensorflow~=2.15.0->tf-models-official>=2.5.1->object-detection==0.1) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /home/pankajs19/Documents/birdet/TFODCourse/tfod/lib/python3.10/site-packages (from tensorflow~=2.15.0->tf-models-official>=2.5.1->object-detection==0.1) (16.0.6)
# Requirement already satisfied: opt-einsum>=2.3.2 in /home/pankajs19/Documents/birdet/TFODCourse/tfod/lib/python3.10/site-packages (from tensorflow~=2.15.0->tf-models-official>=2.5.1->object-detection==0.1) (3.3.0)
# Requirement already satisfied: setuptools in /home/pankajs19/Documents/birdet/TFODCourse/tfod/lib/python3.10/site-packages (from tensorflow~=2.15.0->tf-models-official>=2.5.1->object-detection==0.1) (59.6.0)
# Requirement already satisfied: termcolor>=1.1.0 in /home/pankajs19/Documents/birdet/TFODCourse/tfod/lib/python3.10/site-packages (from tensorflow~=2.15.0->tf-models-official>=2.5.1->object-detection==0.1) (2.4.0)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in /home/pankajs19/Documents/birdet/TFODCourse/tfod/lib/python3.10/site-packages (from tensorflow~=2.15.0->tf-models-official>=2.5.1->object-detection==0.1) (1.14.1)
# Collecting tensorboard<2.16,>=2.15 (from tensorflow~=2.15.0->tf-models-official>=2.5.1->object-detection==0.1)
#   Using cached tensorboard-2.15.2-py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: tensorflow-estimator<2.16,>=2.15.0 in /home/pankajs19/Documents/birdet/TFODCourse/tfod/lib/python3.10/site-packages (from tensorflow~=2.15.0->tf-models-official>=2.5.1->object-detection==0.1) (2.15.0)
# Collecting keras (from object-detection==0.1)
#   Using cached keras-2.15.0-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied:
# I0314 22:14:08.837695 139902116761600 efficientnet_model.py:143] round_filter input=40 output=80
# I0314 22:14:09.452161 139902116761600 efficientnet_model.py:143] round_filter input=40 output=80
# I0314 22:14:09.452279 139902116761600 efficientnet_model.py:143] round_filter input=80 output=160
# I0314 22:14:10.242756 139902116761600 efficientnet_model.py:143] round_filter input=80 output=160
# I0314 22:14:10.242847 139902116761600 efficientnet_model.py:143] round_filter input=112 output=224
# I0314 22:14:11.068118 139902116761600 efficientnet_model.py:143] round_filter input=112 output=224
# I0314 22:14:11.068212 139902116761600 efficientnet_model.py:143] round_filter input=192 output=384
# I0314 22:14:12.229125 139902116761600 efficientnet_model.py:143] round_filter input=192 output=384
# I0314 22:14:12.229230 139902116761600 efficientnet_model.py:143] round_filter input=320 output=640
# I0314 22:14:12.699280 139902116761600 efficientnet_model.py:143] round_filter input=1280 output=2560
# I0314 22:14:12.747920 139902116761600 efficientnet_model.py:453] Building model efficientnet with params ModelConfig(width_coefficient=2.0, depth_coefficient=3.1, resolution=600, dropout_rate=0.5, blocks=(BlockConfig(input_filters=32, output_filters=16, kernel_size=3, num_repeat=1, expand_ratio=1, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=16, output_filters=24, kernel_size=3, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=24, output_filters=40, kernel_size=5, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=40, output_filters=80, kernel_size=3, num_repeat=3, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=80, output_filters=112, kernel_size=5, num_repeat=3, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=112, output_filters=192, kernel_size=5, num_repeat=4, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=192, output_filters=320, kernel_size=3, num_repeat=1, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise')), stem_base_filters=32, top_base_filters=1280, activation='simple_swish', batch_norm='default', bn_momentum=0.99, bn_epsilon=0.001, weight_decay=5e-06, drop_connect_rate=0.2, depth_divisor=8, min_depth=None, use_se=True, input_channels=3, num_classes=1000, model_name='efficientnet', rescale_input=False, data_format='channels_last', dtype='float32')
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_ssd_models_from_config): 22.56s
# I0314 22:14:12.852810 139902116761600 test_util.py:2574] time(__main__.ModelBuilderTF2Test.test_create_ssd_models_from_config): 22.56s
# [       OK ] ModelBuilderTF2Test.test_create_ssd_models_from_config
# [ RUN      ] ModelBuilderTF2Test.test_invalid_faster_rcnn_batchnorm_update
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_invalid_faster_rcnn_batchnorm_update): 0.01s
# I0314 22:14:12.974955 139902116761600 test_util.py:2574] time(__main__.ModelBuilderTF2Test.test_invalid_faster_rcnn_batchnorm_update): 0.01s
# [       OK ] ModelBuilderTF2Test.test_invalid_faster_rcnn_batchnorm_update
# [ RUN      ] ModelBuilderTF2Test.test_invalid_first_stage_nms_iou_threshold
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_invalid_first_stage_nms_iou_threshold): 0.0s
# I0314 22:14:12.976100 139902116761600 test_util.py:2574] time(__main__.ModelBuilderTF2Test.test_invalid_first_stage_nms_iou_threshold): 0.0s
# [       OK ] ModelBuilderTF2Test.test_invalid_first_stage_nms_iou_threshold
# [ RUN      ] ModelBuilderTF2Test.test_invalid_model_config_proto
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_invalid_model_config_proto): 0.0s
# I0314 22:14:12.976379 139902116761600 test_util.py:2574] time(__main__.ModelBuilderTF2Test.test_invalid_model_config_proto): 0.0s
# [       OK ] ModelBuilderTF2Test.test_invalid_model_config_proto
# [ RUN      ] ModelBuilderTF2Test.test_invalid_second_stage_batch_size
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_invalid_second_stage_batch_size): 0.0s
# I0314 22:14:12.977339 139902116761600 test_util.py:2574] time(__main__.ModelBuilderTF2Test.test_invalid_second_stage_batch_size): 0.0s
# [       OK ] ModelBuilderTF2Test.test_invalid_second_stage_batch_size
# [ RUN      ] ModelBuilderTF2Test.test_session
# [  SKIPPED ] ModelBuilderTF2Test.test_session
# [ RUN      ] ModelBuilderTF2Test.test_unknown_faster_rcnn_feature_extractor
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_unknown_faster_rcnn_feature_extractor): 0.0s
# I0314 22:14:12.978219 139902116761600 test_util.py:2574] time(__main__.ModelBuilderTF2Test.test_unknown_faster_rcnn_feature_extractor): 0.0s
# [       OK ] ModelBuilderTF2Test.test_unknown_faster_rcnn_feature_extractor
# [ RUN      ] ModelBuilderTF2Test.test_unknown_meta_architecture
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_unknown_meta_architecture): 0.0s
# I0314 22:14:12.978465 139902116761600 test_util.py:2574] time(__main__.ModelBuilderTF2Test.test_unknown_meta_architecture): 0.0s
# [       OK ] ModelBuilderTF2Test.test_unknown_meta_architecture
# [ RUN      ] ModelBuilderTF2Test.test_unknown_ssd_feature_extractor
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_unknown_ssd_feature_extractor): 0.0s
# I0314 22:14:12.979116 139902116761600 test_util.py:2574] time(__main__.ModelBuilderTF2Test.test_unknown_ssd_feature_extractor): 0.0s
# [       OK ] ModelBuilderTF2Test.test_unknown_ssd_feature_extractor
# ----------------------------------------------------------------------
# Ran 24 tests in 26.674s
#
# OK (skipped=1)

# %%
# !pip uninstall tensorrt -y
# !pip install tensorrt
# Out:
# Found existing installation: tensorrt 8.6.1.post1
# Uninstalling tensorrt-8.6.1.post1:
#   Successfully uninstalled tensorrt-8.6.1.post1
# Collecting tensorrt
#   Using cached tensorrt-8.6.1.post1-py2.py3-none-any.whl
# DEPRECATION: pytorch-lightning 1.8.3.post1 has a non-standard dependency specifier torch>=1.9.*. pip 24.1 will enforce this behaviour change. A possible replacement is to upgrade to a newer version of pytorch-lightning or contact the author to suggest that they release a version with a conforming dependency specifiers. Discussion can be found at https://github.com/pypa/pip/issues/12063
# DEPRECATION: torchsde 0.2.5 has a non-standard dependency specifier numpy>=1.19.*; python_version >= "3.7". pip 24.1 will enforce this behaviour change. A possible replacement is to upgrade to a newer version of torchsde or contact the author to suggest that they release a version with a conforming dependency specifiers. Discussion can be found at https://github.com/pypa/pip/issues/12063
# Installing collected packages: tensorrt
# Successfully installed tensorrt-8.6.1.post1

# %%
# !pip uninstall protobuf matplotlib -y
# !pip install protobuf matplotlib==3.2

# %%
import object_detection

# %%
# !pip list
# Out:
# Package                         Version
# ------------------------------- ---------------
# absl-py                         1.4.0
# aiohttp                         3.9.3
# aiosignal                       1.3.1
# anyio                           4.3.0
# apache-beam                     2.54.0
# argon2-cffi                     23.1.0
# argon2-cffi-bindings            21.2.0
# array-record                    0.5.0
# arrow                           1.3.0
# asttokens                       2.4.1
# astunparse                      1.6.3
# async-lru                       2.0.4
# async-timeout                   4.0.3
# attrs                           23.2.0
# avro-python3                    1.10.2
# Babel                           2.14.0
# beautifulsoup4                  4.12.3
# bleach                          6.1.0
# boltons                         23.1.1
# cachetools                      5.3.3
# certifi                         2024.2.2
# cffi                            1.16.0
# charset-normalizer              3.3.2
# chex                            0.1.85
# click                           8.1.7
# cloudpickle                     2.2.1
# colorama                        0.4.6
# comm                            0.2.1
# contextlib2                     21.6.0
# contourpy                       1.2.0
# crcmod                          1.7
# cryptography                    42.0.5
# cycler                          0.12.1
# Cython                          3.0.8
# debugpy                         1.8.1
# decorator                       5.1.1
# defusedxml                      0.7.1
# dill                            0.3.1.1
# dm-tree                         0.1.8
# dnspython                       2.6.1
# docopt                          0.6.2
# docutils                        0.20.1
# etils                           1.7.0
# exceptiongroup                  1.2.0
# executing                       2.0.1
# fastavro                        1.9.4
# fasteners                       0.19
# fastjsonschema                  2.19.1
# filelock                        3.13.1
# fire                            0.5.0
# flatbuffers                     23.5.26
# flax                            0.8.1
# fonttools                       4.49.0
# fqdn                            1.5.1
# frozenlist                      1.4.1
# fsspec                          2024.2.0
# gast                            0.4.0
# gin-config                      0.5.0
# google-api-core                 2.17.1
# google-api-python-client        2.119.0
# google-auth                     2.28.1
# google-auth-httplib2            0.2.0
# google-auth-oauthlib            1.0.0
# google-pasta                    0.2.0
# googleapis-common-protos        1.62.0
# grpcio                          1.62.0
# h11                             0.14.0
# h5py                            3.10.0
# hdfs                            2.7.3
# httpcore                        1.0.4
# httplib2                        0.22.0
# httpx                           0.27.0
# idna                            3.6
# immutabledict                   4.1.0
# importlib-metadata              7.0.1
# importlib_resources             6.1.2
# ipykernel                       6.29.3
# ipython                         8.22.1
# ipywidgets                      8.1.2
# isoduration                     20.11.0
# jaraco.classes                  3.3.1
# jax                             0.4.25
# jaxlib                          0.4.25
# jedi                            0.19.1
# jeepney                         0.8.0
# Jinja2                          3.1.3
# joblib                          1.3.2
# Js2Py                           0.74
# json5                           0.9.17
# jsonpickle                      3.0.3
# jsonpointer                     2.4
# jsonschema                      4.21.1
# jsonschema-specifications       2023.12.1
# jupyter                         1.0.0
# jupyter_client                  8.6.0
# jupyter-console                 6.6.3
# jupyter_core                    5.7.1
# jupyter-events                  0.9.0
# jupyter-lsp                     2.2.3
# jupyter_server                  2.12.5
# jupyter_server_terminals        0.5.2
# jupyterlab                      4.1.2
# jupyterlab_pygments             0.3.0
# jupyterlab_server               2.25.3
# jupyterlab_widgets              3.0.10
# kaggle                          1.6.6
# keras                           3.0.5
# keyring                         24.3.1
# kiwisolver                      1.4.5
# libclang                        16.0.6
# lightning-utilities             0.3.0
# lvis                            0.5.3
# lxml                            5.1.0
# Markdown                        3.5.2
# markdown-it-py                  3.0.0
# MarkupSafe                      2.1.5
# matplotlib                      3.8.3
# matplotlib-inline               0.1.6
# mdurl                           0.1.2
# mistune                         3.0.2
# ml-dtypes                       0.3.2
# more-itertools                  10.2.0
# mpmath                          1.3.0
# msgpack                         1.0.7
# multidict                       6.0.5
# namex                           0.0.7
# nbclient                        0.9.0
# nbconvert                       7.16.1
# nbformat                        5.9.2
# nest-asyncio                    1.6.0
# networkx                        3.2.1
# nh3                             0.2.15
# notebook                        7.1.1
# notebook_shim                   0.2.4
# numpy                           1.24.3
# nvidia-cublas-cu12              12.1.3.1
# nvidia-cuda-cupti-cu12          12.1.105
# nvidia-cuda-nvrtc-cu12          12.1.105
# nvidia-cuda-runtime-cu12        12.1.105
# nvidia-cudnn-cu12               8.9.2.26
# nvidia-cufft-cu12               11.0.2.54
# nvidia-curand-cu12              10.3.2.106
# nvidia-cusolver-cu12            11.4.5.107
# nvidia-cusparse-cu12            12.1.0.106
# nvidia-nccl-cu12                2.19.3
# nvidia-nvjitlink-cu12           12.3.101
# nvidia-nvtx-cu12                12.1.105
# oauth2client                    4.1.3
# oauthlib                        3.2.2
# object-detection                0.1
# objsize                         0.7.0
# opencv-contrib-python           4.9.0.80
# opencv-python                   4.9.0.80
# opencv-python-headless          4.9.0.80
# opt-einsum                      3.3.0
# optax                           0.1.9
# orbax-checkpoint                0.4.4
# orjson                          3.9.15
# overrides                       7.7.0
# packaging                       23.2
# pandas                          1.3.5
# pandocfilters                   1.5.1
# parso                           0.8.3
# pexpect                         4.9.0
# pillow                          10.2.0
# pip                             24.0
# pkginfo                         1.9.6
# platformdirs                    4.2.0
# portalocker                     2.8.2
# prometheus_client               0.20.0
# promise                         2.3
# prompt-toolkit                  3.0.43
# proto-plus                      1.23.0
# protobuf                        3.20.3
# psutil                          5.9.8
# ptyprocess                      0.7.0
# pure-eval                       0.2.2
# py-cpuinfo                      9.0.0
# pyarrow                         14.0.2
# pyarrow-hotfix                  0.6
# pyasn1                          0.5.1
# pyasn1-modules                  0.3.0
# pycocotools                     2.0.7
# pycparser                       2.21
# pydot                           1.4.2
# Pygments                        2.17.2
# pyjsparser                      2.7.1
# pymongo                         4.6.2
# pyparsing                       2.4.7
# PySimpleGUI                     4.60.4
# python-dateutil                 2.8.2
# python-json-logger              2.0.7
# python-slugify                  8.0.4
# pytorch-lightning               1.8.3.post1
# pytz                            2024.1
# PyYAML                          6.0.1
# pyzmq                           25.1.2
# qtconsole                       5.5.1
# QtPy                            2.4.1
# readme_renderer                 43.0
# referencing                     0.33.0
# regex                           2023.12.25
# requests                        2.31.0
# requests-oauthlib               1.3.1
# requests-toolbelt               1.0.0
# rfc3339-validator               0.1.4
# rfc3986                         2.0.0
# rfc3986-validator               0.1.1
# rich                            13.7.0
# rpds-py                         0.18.0
# rsa                             4.9
# sacrebleu                       2.2.0
# safetensors                     0.2.5
# scikit-learn                    1.4.1.post1
# scipy                           1.12.0
# SecretStorage                   3.3.3
# Send2Trash                      1.8.2
# sentencepiece                   0.2.0
# seqeval                         1.2.2
# setuptools                      59.6.0
# six                             1.16.0
# sniffio                         1.3.1
# soupsieve                       2.5
# stack-data                      0.6.3
# sympy                           1.12
# tabulate                        0.9.0
# tensorboard                     2.16.2
# tensorboard-data-server         0.7.2
# tensorboardX                    2.6.2.2
# tensorflow                      2.16.1
# tensorflow-datasets             4.9.4
# tensorflow-decision-forests     1.8.1
# tensorflow-estimator            2.15.0
# tensorflow-hub                  0.16.1
# tensorflow-io                   0.36.0
# tensorflow-io-gcs-filesystem    0.36.0
# tensorflow-metadata             1.14.0
# tensorflow-model-optimization   0.8.0
# tensorflow-object-detection-api 0.1.1
# tensorflow-text                 2.15.0
# tensorflowjs                    4.17.0
# tensorrt                        8.6.1.post1
# tensorrt-bindings               8.6.1
# tensorrt-libs                   8.6.1
# tensorstore                     0.1.45
# termcolor                       2.4.0
# terminado                       0.18.0
# text-unidecode                  1.3
# tf-keras                        2.15.0
# tf-models-official              2.15.0
# tf-slim                         1.1.0
# threadpoolctl                   3.3.0
# tinycss2                        1.2.1
# tk                              0.1.0
# toml                            0.10.2
# tomli                           2.0.1
# toolz                           0.12.1
# torch                           2.2.1
# torchmetrics                    0.11.4
# torchsde                        0.2.5
# tornado                         6.4
# tqdm                            4.66.2
# traitlets                       5.14.1
# trampoline                      0.1.2
# triton                          2.2.0
# twine                           5.0.0
# types-python-dateutil           2.8.19.20240106
# typing_extensions               4.5.0
# tzdata                          2024.1
# tzlocal                         5.2
# uri-template                    1.3.0
# uritemplate                     4.1.1
# urllib3                         2.2.1
# wcwidth                         0.2.13
# webcolors                       1.13
# webencodings                    0.5.1
# websocket-client                1.7.0
# Werkzeug                        3.0.1
# wheel                           0.42.0
# widgetsnbextension              4.0.10
# wrapt                           1.14.1
# wurlitzer                       3.0.3
# yarl                            1.9.4
# zipp                            3.17.0
# zstandard                       0.22.0

# %%
if os.name =='posix':
    # !wget {PRETRAINED_MODEL_URL}
    # !mv {PRETRAINED_MODEL_NAME+'.tar.gz'} {paths['PRETRAINED_MODEL_PATH']}
    # !cd {paths['PRETRAINED_MODEL_PATH']} && tar -zxvf {PRETRAINED_MODEL_NAME+'.tar.gz'}
if os.name == 'nt':
    wget.download(PRETRAINED_MODEL_URL)
    # !move {PRETRAINED_MODEL_NAME+'.tar.gz'} {paths['PRETRAINED_MODEL_PATH']}
    # !cd {paths['PRETRAINED_MODEL_PATH']} && tar -zxvf {PRETRAINED_MODEL_NAME+'.tar.gz'}
# Out:
# --
model_lib_v2.py:1018] 	+ Loss/classification_loss: 0.416467
# INFO:tensorflow:	+ Loss/regularization_loss: 0.106144
# I0319 10:13:27.753951 140008716914688 model_lib_v2.py:1018] 	+ Loss/regularization_loss: 0.106144
# INFO:tensorflow:	+ Loss/total_loss: 0.758116
# I0319 10:13:27.754373 140008716914688 model_lib_v2.py:1018] 	+ Loss/total_loss: 0.758116
# ^C
# Traceback (most recent call last):
#   File "/home/pankajs19/Documents/birdet/TFODCourse/Tensorflow/models/research/object_detection/model_main_tf2.py", line 114, in <module>
#     tf.compat.v1.app.run()
#   File "/home/pankajs19/Documents/birdet/TFODCourse/tfod/lib/python3.10/site-packages/tensorflow/python/platform/app.py", line 36, in run
#     _run(main=main, argv=argv, flags_parser=_parse_flags_tolerate_undef)
#   File "/home/pankajs19/Documents/birdet/TFODCourse/tfod/lib/python3.10/site-packages/absl/app.py", line 308, in run
#     _run_main(main, args)
#   File "/home/pankajs19/Documents/birdet/TFODCourse/tfod/lib/python3.10/site-packages/absl/app.py", line 254, in _run_main
#     sys.exit(main(argv))
#   File "/home/pankajs19/Documents/birdet/TFODCourse/Tensorflow/models/research/object_detection/model_main_tf2.py", line 81, in main
#     model_lib_v2.eval_continuously(
#   File "/home/pankajs19/Documents/birdet/TFODCourse/tfod/lib/python3.10/site-packages/object_detection/model_lib_v2.py", line 1135, in eval_continuously
#     for latest_checkpoint in tf.train.checkpoints_iterator(
#   File "/home/pankajs19/Documents/birdet/TFODCourse/tfod/lib/python3.10/site-packages/tensorflow/python/training/checkpoint_utils.py", line 244, in checkpoints_iterator
#     time.sleep(time_to_next_eval)
# KeyboardInterrupt

# %% [markdown]
# # 8. Load Train Model From Checkpoint

# %%
# !pip install tensorrt

# %%
import os
import tensorflow as tf
from object_detection.utils import label_map_util
from object_detection.utils import visualization_utils as viz_utils
from object_detection.builders import model_builder
from object_detection.utils import config_util

# %%
# Load pipeline config and build a detection model
configs = config_util.get_configs_from_pipeline_file(files['PIPELINE_CONFIG'])
detection_model = model_builder.build(model_config=configs['model'], is_training=False)

# Restore checkpoint
ckpt = tf.compat.v2.train.Checkpoint(model=detection_model)
ckpt.restore(os.path.join(paths['CHECKPOINT_PATH'], 'ckpt-9')).expect_partial()

@tf.function
def detect_fn(image):
    image, shapes = detection_model.preprocess(image)
    prediction_dict = detection_model.predict(image, shapes)
    detections = detection_model.postprocess(prediction_dict, shapes)
    return detections

# %% [markdown]
# # 9. Detect from an Image

# %%
import cv2 
import numpy as np
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
category_index = label_map_util.create_category_index_from_labelmap(files['LABELMAP'])

# %%
IMAGE_PATH = os.path.join(paths['IMAGE_PATH'], 'test', 'flock.jpeg')

# %%
img = cv2.imread(IMAGE_PATH)
image_np = np.array(img)

input_tensor = tf.convert_to_tensor(np.expand_dims(image_np, 0), dtype=tf.float32)
detections = detect_fn(input_tensor)

num_detections = int(detections.pop('num_detections'))
detections = {key: value[0, :num_detections].numpy()
              for key, value in detections.items()}
detections['num_detections'] = num_detections

# detection_classes should be ints.
detections['detection_classes'] = detections['detection_classes'].astype(np.int64)

label_id_offset = 1
image_np_with_detections = image_np.copy()

viz_utils.visualize_boxes_and_labels_on_image_array(
            image_np_with_detections,
            detections['detection_boxes'],
            detections['detection_classes']+label_id_offset,
            detections['detection_scores'],
            category_index,
            use_normalized_coordinates=True,
            max_boxes_to_draw=5,
            min_score_thresh=.8,
            agnostic_mode=False)

plt.imshow(cv2.cvtColor(image_np_with_detections, cv2.COLOR_BGR2RGB))
plt.show()
# Out:
# WARNING:tensorflow:5 out of the last 5 calls to <function detect_fn at 0x7f173cec37f0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:5 out of the last 5 calls to <function detect_fn at 0x7f173cec37f0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.

# %%
IMAGE_PATH = os.path.join(paths['IMAGE_PATH'], 'test','No', 'bird.jpg')

# %%
img = cv2.imread(IMAGE_PATH)
image_np = np.array(img)

input_tensor = tf.convert_to_tensor(np.expand_dims(image_np, 0), dtype=tf.float32)
detections = detect_fn(input_tensor)

num_detections = int(detections.pop('num_detections'))
detections = {key: value[0, :num_detections].numpy()
              for key, value in detections.items()}
detections['num_detections'] = num_detections

# detection_classes should be ints.
detections['detection_classes'] = detections['detection_classes'].astype(np.int64)

label_id_offset = 1
image_np_with_detections = image_np.copy()

viz_utils.visualize_boxes_and_labels_on_image_array(
            image_np_with_detections,
            detections['detection_boxes'],
            detections['detection_classes']+label_id_offset,
            detections['detection_scores'],
            category_index,
            use_normalized_coordinates=True,
            max_boxes_to_draw=5,
            min_score_thresh=.8,
            agnostic_mode=False)

plt.imshow(cv2.cvtColor(image_np_with_detections, cv2.COLOR_BGR2RGB))
plt.show()

# %%
# !pip uninstall opencv-python -y
# !pip install opencv-python --upgrade

# %% [markdown]
# # 10. Real Time Detections from your Webcam

# %%
import cv2 

cap = cv2.VideoCapture(0)
width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))

while cap.isOpened(): 
    ret, frame = cap.read()
    image_np = np.array(frame)
    
    input_tensor = tf.convert_to_tensor(np.expand_dims(image_np, 0), dtype=tf.float32)
    detections = detect_fn(input_tensor)
    
    num_detections = int(detections.pop('num_detections'))
    detections = {key: value[0, :num_detections].numpy()
                  for key, value in detections.items()}
    detections['num_detections'] = num_detections

    # detection_classes should be ints.
    detections['detection_classes'] = detections['detection_classes'].astype(np.int64)

    label_id_offset = 1
    image_np_with_detections = image_np.copy()

    viz_utils.visualize_boxes_and_labels_on_image_array(
                image_np_with_detections,
                detections['detection_boxes'],
                detections['detection_classes']+label_id_offset,
                detections['detection_scores'],
                category_index,
                use_normalized_coordinates=True,
                max_boxes_to_draw=5,
                min_score_thresh=.8,
                agnostic_mode=False)

    cv2.imshow('object detection',  cv2.resize(image_np_with_detections, (800, 600)))
    
    if cv2.waitKey(10) & 0xFF == ord('q'):
        cap.release()
        cv2.destroyAllWindows()
        break

# %%
video_path = os.path.join(paths['IMAGE_PATH'], 'test','videos5' ,'SV8.mp4')

# %%
import cv2 

cap = cv2.VideoCapture(video_path)
width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))

while cap.isOpened(): 
    ret, frame = cap.read()
    image_np = np.array(frame)
    
    input_tensor = tf.convert_to_tensor(np.expand_dims(image_np, 0), dtype=tf.float32)
    detections = detect_fn(input_tensor)
    
    num_detections = int(detections.pop('num_detections'))
    detections = {key: value[0, :num_detections].numpy()
                  for key, value in detections.items()}
    detections['num_detections'] = num_detections

    # detection_classes should be ints.
    detections['detection_classes'] = detections['detection_classes'].astype(np.int64)

    label_id_offset = 1
    image_np_with_detections = image_np.copy()

    viz_utils.visualize_boxes_and_labels_on_image_array(
                image_np_with_detections,
                detections['detection_boxes'],
                detections['detection_classes']+label_id_offset,
                detections['detection_scores'],
                category_index,
                use_normalized_coordinates=True,
                max_boxes_to_draw=5,
                min_score_thresh=.8,
                agnostic_mode=False)

    cv2.imshow('object detection',  cv2.resize(image_np_with_detections, (800, 600)))
    
    if cv2.waitKey(10) & 0xFF == ord('q'):
        cap.release()
        cv2.destroyAllWindows()
        break

# %% [markdown]
# # 10. Freezing the Graph

# %%
FREEZE_SCRIPT = os.path.join(paths['APIMODEL_PATH'], 'research', 'object_detection', 'exporter_main_v2.py ')

# %%
command = "python {} --input_type=image_tensor --pipeline_config_path={} --trained_checkpoint_dir={} --output_directory={}".format(FREEZE_SCRIPT ,files['PIPELINE_CONFIG'], paths['CHECKPOINT_PATH'], paths['OUTPUT_PATH'])

# %%
print(command)
# Out:
# python Tensorflow/models/research/object_detection/exporter_main_v2.py  --input_type=image_tensor --pipeline_config_path=Tensorflow/workspace/models/my_ssd_mobnet_v9.2/pipeline.config --trained_checkpoint_dir=Tensorflow/workspace/models/my_ssd_mobnet_v9.2 --output_directory=Tensorflow/workspace/models/my_ssd_mobnet_v9.2/export

# %%
# !{command}
# Out:
# /usr/lib/python3.10/pty.py:89: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   pid, fd = os.forkpty()
# 2024-03-27 23:18:53.879087: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-03-27 23:18:55.720197: E tensorflow/compiler/xla/stream_executor/cuda/cuda_driver.cc:268] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# WARNING:tensorflow:From /home/pankajs19/Documents/birdet/TFODCourse/tfod/lib/python3.10/site-packages/tensorflow/python/autograph/impl/api.py:459: calling map_fn_v2 (from tensorflow.python.ops.map_fn) with back_prop=False is deprecated and will be removed in a future version.
# Instructions for updating:
# back_prop=False is deprecated. Consider using tf.stop_gradient instead.
# Instead of:
# results = tf.map_fn(fn, elems, back_prop=False)
# Use:
# results = tf.nest.map_structure(tf.stop_gradient, tf.map_fn(fn, elems))
# W0327 23:18:55.940076 139631138881536 deprecation.py:641] From /home/pankajs19/Documents/birdet/TFODCourse/tfod/lib/python3.10/site-packages/tensorflow/python/autograph/impl/api.py:459: calling map_fn_v2 (from tensorflow.python.ops.map_fn) with back_prop=False is deprecated and will be removed in a future version.
# Instructions for updating:
# back_prop=False is deprecated. Consider using tf.stop_gradient instead.
# Instead of:
# results = tf.map_fn(fn, elems, back_prop=False)
# Use:
# results = tf.nest.map_structure(tf.stop_gradient, tf.map_fn(fn, elems))
# I0327 23:18:58.817183 139631138881536 api.py:460] feature_map_spatial_dims: [(40, 40), (20, 20), (10, 10), (5, 5), (3, 3)]
# I0327 23:19:04.542188 139631138881536 api.py:460] feature_map_spatial_dims: [(40, 40), (20, 20), (10, 10), (5, 5), (3, 3)]
# I0327 23:19:06.079906 139631138881536 signature_serialization.py:148] Function `call_func` contains input name(s) resource with unsupported characters which will be renamed to weightsharedconvolutionalboxpredictor_predictiontower_conv2d_3_batchnorm_feature_4_fusedbatchnormv3_readvariableop_1_resource in the SavedModel.
# I0327 23:19:06.866137 139631138881536 api.py:460] feature_map_spatial_dims: [(40, 40), (20, 20), (10, 10), (5, 5), (3, 3)]
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.meta_architectures.ssd_meta_arch.SSDMetaArch object at 0x7efde21b5450>, because it is not built.
# W0327 23:19:08.151585 139631138881536 save_impl.py:66] Skipping full serialization of Keras layer <object_detection.meta_architectures.ssd_meta_arch.SSDMetaArch object at 0x7efde21b5450>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.src.layers.convolutional.separable_conv2d.SeparableConv2D object at 0x7efdd1f0cf70>, because it is not built.
# W0327 23:19:08.457307 139631138881536 save_impl.py:66] Skipping full serialization of Keras layer <keras.src.layers.convolutional.separable_conv2d.SeparableConv2D object at 0x7efdd1f0cf70>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7efde015ddb0>, because it is not built.
# W0327 23:19:08.457419 139631138881536 save_impl.py:66] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7efde015ddb0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.src.layers.core.lambda_layer.Lambda object at 0x7efde015f9d0>, because it is not built.
# W0327 23:19:08.457475 139631138881536 save_impl.py:66] Skipping full serialization of Keras layer <keras.src.layers.core.lambda_layer.Lambda object at 0x7efde015f9d0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.src.layers.convolutional.separable_conv2d.SeparableConv2D object at 0x7efde015dba0>, because it is not built.
# W0327 23:19:08.457523 139631138881536 save_impl.py:66] Skipping full serialization of Keras layer <keras.src.layers.convolutional.separable_conv2d.SeparableConv2D object at 0x7efde015dba0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7efdd1e5ca60>, because it is not built.
# W0327 23:19:08.457567 139631138881536 save_impl.py:66] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7efdd1e5ca60>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.src.layers.core.lambda_layer.Lambda object at 0x7efdd1e5f2e0>, because it is not built.
# W0327 23:19:08.457609 139631138881536 save_impl.py:66] Skipping full serialization of Keras layer <keras.src.layers.core.lambda_layer.Lambda object at 0x7efdd1e5f2e0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.src.layers.convolutional.separable_conv2d.SeparableConv2D object at 0x7efdd1e5f9d0>, because it is not built.
# W0327 23:19:08.457650 139631138881536 save_impl.py:66] Skipping full serialization of Keras layer <keras.src.layers.convolutional.separable_conv2d.SeparableConv2D object at 0x7efdd1e5f9d0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7efdd1b923e0>, because it is not built.
# W0327 23:19:08.457690 139631138881536 save_impl.py:66] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7efdd1b923e0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.src.layers.core.lambda_layer.Lambda object at 0x7efdd1b92fe0>, because it is not built.
# W0327 23:19:08.457730 139631138881536 save_impl.py:66] Skipping full serialization of Keras layer <keras.src.layers.core.lambda_layer.Lambda object at 0x7efdd1b92fe0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.src.layers.convolutional.separable_conv2d.SeparableConv2D object at 0x7efdd1b904f0>, because it is not built.
# W0327 23:19:08.457770 139631138881536 save_impl.py:66] Skipping full serialization of Keras layer <keras.src.layers.convolutional.separable_conv2d.SeparableConv2D object at 0x7efdd1b904f0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7efdd1b92bf0>, because it is not built.
# W0327 23:19:08.457809 139631138881536 save_impl.py:66] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7efdd1b92bf0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.src.layers.core.lambda_layer.Lambda object at 0x7efdd1b92650>, because it is not built.
# W0327 23:19:08.457850 139631138881536 save_impl.py:66] Skipping full serialization of Keras layer <keras.src.layers.core.lambda_layer.Lambda object at 0x7efdd1b92650>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7efdd1b922f0>, because it is not built.
# W0327 23:19:08.457893 139631138881536 save_impl.py:66] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7efdd1b922f0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.src.layers.core.lambda_layer.Lambda object at 0x7efdd1b91d80>, because it is not built.
# W0327 23:19:08.457941 139631138881536 save_impl.py:66] Skipping full serialization of Keras layer <keras.src.layers.core.lambda_layer.Lambda object at 0x7efdd1b91d80>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7efde01ab6d0>, because it is not built.
# W0327 23:19:08.457992 139631138881536 save_impl.py:66] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7efde01ab6d0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.src.layers.core.lambda_layer.Lambda object at 0x7efde01aa8f0>, because it is not built.
# W0327 23:19:08.458038 139631138881536 save_impl.py:66] Skipping full serialization of Keras layer <keras.src.layers.core.lambda_layer.Lambda object at 0x7efde01aa8f0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7efdd1e72260>, because it is not built.
# W0327 23:19:08.458083 139631138881536 save_impl.py:66] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7efdd1e72260>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.src.layers.core.lambda_layer.Lambda object at 0x7efdd1b80be0>, because it is not built.
# W0327 23:19:08.458128 139631138881536 save_impl.py:66] Skipping full serialization of Keras layer <keras.src.layers.core.lambda_layer.Lambda object at 0x7efdd1b80be0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7efdd1b81b10>, because it is not built.
# W0327 23:19:08.458173 139631138881536 save_impl.py:66] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7efdd1b81b10>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.src.layers.core.lambda_layer.Lambda object at 0x7efdd1b51330>, because it is not built.
# W0327 23:19:08.458217 139631138881536 save_impl.py:66] Skipping full serialization of Keras layer <keras.src.layers.core.lambda_layer.Lambda object at 0x7efdd1b51330>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7efdd1b53c10>, because it is not built.
# W0327 23:19:08.458263 139631138881536 save_impl.py:66] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7efdd1b53c10>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.src.layers.core.lambda_layer.Lambda object at 0x7efdd1b49300>, because it is not built.
# W0327 23:19:08.458307 139631138881536 save_impl.py:66] Skipping full serialization of Keras layer <keras.src.layers.core.lambda_layer.Lambda object at 0x7efdd1b49300>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7efdd1b48970>, because it is not built.
# W0327 23:19:08.458352 139631138881536 save_impl.py:66] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7efdd1b48970>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.src.layers.core.lambda_layer.Lambda object at 0x7efdd1b48400>, because it is not built.
# W0327 23:19:08.458397 139631138881536 save_impl.py:66] Skipping full serialization of Keras layer <keras.src.layers.core.lambda_layer.Lambda object at 0x7efdd1b48400>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7efdd1b49240>, because it is not built.
# W0327 23:19:08.458441 139631138881536 save_impl.py:66] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7efdd1b49240>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.src.layers.core.lambda_layer.Lambda object at 0x7efdd1b48490>, because it is not built.
# W0327 23:19:08.458486 139631138881536 save_impl.py:66] Skipping full serialization of Keras layer <keras.src.layers.core.lambda_layer.Lambda object at 0x7efdd1b48490>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7efdd1959a20>, because it is not built.
# W0327 23:19:08.458531 139631138881536 save_impl.py:66] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7efdd1959a20>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.src.layers.core.lambda_layer.Lambda object at 0x7efdd1959ae0>, because it is not built.
# W0327 23:19:08.458576 139631138881536 save_impl.py:66] Skipping full serialization of Keras layer <keras.src.layers.core.lambda_layer.Lambda object at 0x7efdd1959ae0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7efdd195a320>, because it is not built.
# W0327 23:19:08.458620 139631138881536 save_impl.py:66] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7efdd195a320>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.src.layers.core.lambda_layer.Lambda object at 0x7efde01d5390>, because it is not built.
# W0327 23:19:08.458687 139631138881536 save_impl.py:66] Skipping full serialization of Keras layer <keras.src.layers.core.lambda_layer.Lambda object at 0x7efde01d5390>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7efde01d4340>, because it is not built.
# W0327 23:19:08.458750 139631138881536 save_impl.py:66] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7efde01d4340>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.src.layers.core.lambda_layer.Lambda object at 0x7efde01d5e40>, because it is not built.
# W0327 23:19:08.458795 139631138881536 save_impl.py:66] Skipping full serialization of Keras layer <keras.src.layers.core.lambda_layer.Lambda object at 0x7efde01d5e40>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7efde01d48e0>, because it is not built.
# W0327 23:19:08.458839 139631138881536 save_impl.py:66] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7efde01d48e0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.src.layers.core.lambda_layer.Lambda object at 0x7efde01d6620>, because it is not built.
# W0327 23:19:08.458884 139631138881536 save_impl.py:66] Skipping full serialization of Keras layer <keras.src.layers.core.lambda_layer.Lambda object at 0x7efde01d6620>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7efde01d4b50>, because it is not built.
# W0327 23:19:08.458929 139631138881536 save_impl.py:66] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7efde01d4b50>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.src.layers.core.lambda_layer.Lambda object at 0x7efde01d49a0>, because it is not built.
# W0327 23:19:08.458977 139631138881536 save_impl.py:66] Skipping full serialization of Keras layer <keras.src.layers.core.lambda_layer.Lambda object at 0x7efde01d49a0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7efdd1e91f90>, because it is not built.
# W0327 23:19:08.459022 139631138881536 save_impl.py:66] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7efdd1e91f90>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.src.layers.core.lambda_layer.Lambda object at 0x7efdd1fcff10>, because it is not built.
# W0327 23:19:08.459067 139631138881536 save_impl.py:66] Skipping full serialization of Keras layer <keras.src.layers.core.lambda_layer.Lambda object at 0x7efdd1fcff10>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7efdd1fcf370>, because it is not built.
# W0327 23:19:08.459112 139631138881536 save_impl.py:66] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7efdd1fcf370>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.src.layers.core.lambda_layer.Lambda object at 0x7efdd1fcd390>, because it is not built.
# W0327 23:19:08.459156 139631138881536 save_impl.py:66] Skipping full serialization of Keras layer <keras.src.layers.core.lambda_layer.Lambda object at 0x7efdd1fcd390>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7efdd1fcc1f0>, because it is not built.
# W0327 23:19:08.459202 139631138881536 save_impl.py:66] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7efdd1fcc1f0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.src.layers.core.lambda_layer.Lambda object at 0x7efdd1fcfd90>, because it is not built.
# W0327 23:19:08.459246 139631138881536 save_impl.py:66] Skipping full serialization of Keras layer <keras.src.layers.core.lambda_layer.Lambda object at 0x7efdd1fcfd90>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7efdd1fcc370>, because it is not built.
# W0327 23:19:08.459290 139631138881536 save_impl.py:66] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7efdd1fcc370>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.src.layers.core.lambda_layer.Lambda object at 0x7efdd1fccbe0>, because it is not built.
# W0327 23:19:08.459334 139631138881536 save_impl.py:66] Skipping full serialization of Keras layer <keras.src.layers.core.lambda_layer.Lambda object at 0x7efdd1fccbe0>, because it is not built.
# I0327 23:19:16.216712 139631138881536 save.py:274] Found untraced functions such as WeightSharedConvolutionalBoxPredictor_layer_call_fn, WeightSharedConvolutionalBoxPredictor_layer_call_and_return_conditional_losses, WeightSharedConvolutionalBoxHead_layer_call_fn, WeightSharedConvolutionalBoxHead_layer_call_and_return_conditional_losses, WeightSharedConvolutionalClassHead_layer_call_fn while saving (showing 5 of 173). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Tensorflow/workspace/models/my_ssd_mobnet_v9.2/export/saved_model/assets
# I0327 23:19:20.041580 139631138881536 builder_impl.py:804] Assets written to: Tensorflow/workspace/models/my_ssd_mobnet_v9.2/export/saved_model/assets
# I0327 23:19:20.264396 139631138881536 fingerprinting_utils.py:48] Writing fingerprint to Tensorflow/workspace/models/my_ssd_mobnet_v9.2/export/saved_model/fingerprint.pb
# INFO:tensorflow:Writing pipeline config file to Tensorflow/workspace/models/my_ssd_mobnet_v9.2/export/pipeline.config
# I0327 23:19:20.630017 139631138881536 config_util.py:253] Writing pipeline config file to Tensorflow/workspace/models/my_ssd_mobnet_v9.2/export/pipeline.config

# %% [markdown]
# # 11. Conversion to TFJS

# %%
# !pip install tensorflowjs

# %%
command = "tensorflowjs_converter --input_format=tf_saved_model --output_node_names='detection_boxes,detection_classes,detection_features,detection_multiclass_scores,detection_scores,num_detections,raw_detection_boxes,raw_detection_scores' --output_format=tfjs_graph_model --signature_name=serving_default {} {}".format(os.path.join(paths['OUTPUT_PATH'], 'saved_model'), paths['TFJS_PATH'])

# %%
print(command)
# Out:
# tensorflowjs_converter --input_format=tf_saved_model --output_node_names='detection_boxes,detection_classes,detection_features,detection_multiclass_scores,detection_scores,num_detections,raw_detection_boxes,raw_detection_scores' --output_format=tfjs_graph_model --signature_name=serving_default Tensorflow/workspace/models/my_ssd_mobnet_v8/export/saved_model Tensorflow/workspace/models/my_ssd_mobnet_v8/tfjsexport

# %%
# !{command}
# Out:
# 2024-03-15 17:30:35.596094: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# WARNING:root:TensorFlow Decision Forests 1.8.1 is compatible with the following TensorFlow Versions: ['2.15.0']. However, TensorFlow 2.13.0 was detected. This can cause issues with the TF API and symbols in the custom C++ ops. See the TF and TF-DF compatibility table at https://github.com/tensorflow/decision-forests/blob/main/documentation/known_issues.md#compatibility-table.
# 2024-03-15 17:30:38.108811: E tensorflow/compiler/xla/stream_executor/cuda/cuda_driver.cc:268] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected

# %% [markdown]
# # 12. Conversion to TFLite

# %%
TFLITE_SCRIPT = os.path.join(paths['APIMODEL_PATH'], 'research', 'object_detection', 'export_tflite_graph_tf2.py ')

# %%
command = "python {} --pipeline_config_path={} --trained_checkpoint_dir={} --output_directory={}".format(TFLITE_SCRIPT ,files['PIPELINE_CONFIG'], paths['CHECKPOINT_PATH'], paths['TFLITE_PATH'])

# %%
print(command)
# Out:
# python Tensorflow/models/research/object_detection/export_tflite_graph_tf2.py  --pipeline_config_path=Tensorflow/workspace/models/my_ssd_mobnet_v9.2/pipeline.config --trained_checkpoint_dir=Tensorflow/workspace/models/my_ssd_mobnet_v9.2 --output_directory=Tensorflow/workspace/models/my_ssd_mobnet_v9.2/tfliteexport

# %%
# !{command}
# Out:
# 2024-03-27 23:19:29.925821: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-03-27 23:19:31.769355: E tensorflow/compiler/xla/stream_executor/cuda/cuda_driver.cc:268] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# I0327 23:19:34.118549 139749666430976 api.py:460] feature_map_spatial_dims: [(40, 40), (20, 20), (10, 10), (5, 5), (3, 3)]
# I0327 23:19:36.932599 139749666430976 api.py:460] feature_map_spatial_dims: [(40, 40), (20, 20), (10, 10), (5, 5), (3, 3)]
# I0327 23:19:37.762917 139749666430976 signature_serialization.py:148] Function `inference_fn` contains input name(s) resource with unsupported characters which will be renamed to weightsharedconvolutionalboxpredictor_predictiontower_conv2d_3_batchnorm_feature_4_fusedbatchnormv3_readvariableop_1_resource in the SavedModel.
# I0327 23:19:38.483738 139749666430976 api.py:460] feature_map_spatial_dims: [(40, 40), (20, 20), (10, 10), (5, 5), (3, 3)]
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.meta_architectures.ssd_meta_arch.SSDMetaArch object at 0x7f197b2d39d0>, because it is not built.
# W0327 23:19:39.265657 139749666430976 save_impl.py:66] Skipping full serialization of Keras layer <object_detection.meta_architectures.ssd_meta_arch.SSDMetaArch object at 0x7f197b2d39d0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.src.layers.convolutional.separable_conv2d.SeparableConv2D object at 0x7f19785c2a10>, because it is not built.
# W0327 23:19:39.463734 139749666430976 save_impl.py:66] Skipping full serialization of Keras layer <keras.src.layers.convolutional.separable_conv2d.SeparableConv2D object at 0x7f19785c2a10>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f193e6a8eb0>, because it is not built.
# W0327 23:19:39.463843 139749666430976 save_impl.py:66] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f193e6a8eb0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.src.layers.core.lambda_layer.Lambda object at 0x7f193e6a9ea0>, because it is not built.
# W0327 23:19:39.463898 139749666430976 save_impl.py:66] Skipping full serialization of Keras layer <keras.src.layers.core.lambda_layer.Lambda object at 0x7f193e6a9ea0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.src.layers.convolutional.separable_conv2d.SeparableConv2D object at 0x7f193e6a9210>, because it is not built.
# W0327 23:19:39.463944 139749666430976 save_impl.py:66] Skipping full serialization of Keras layer <keras.src.layers.convolutional.separable_conv2d.SeparableConv2D object at 0x7f193e6a9210>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f193e6aa170>, because it is not built.
# W0327 23:19:39.463988 139749666430976 save_impl.py:66] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f193e6aa170>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.src.layers.core.lambda_layer.Lambda object at 0x7f193e6a80a0>, because it is not built.
# W0327 23:19:39.464030 139749666430976 save_impl.py:66] Skipping full serialization of Keras layer <keras.src.layers.core.lambda_layer.Lambda object at 0x7f193e6a80a0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.src.layers.convolutional.separable_conv2d.SeparableConv2D object at 0x7f193e6a9ab0>, because it is not built.
# W0327 23:19:39.464070 139749666430976 save_impl.py:66] Skipping full serialization of Keras layer <keras.src.layers.convolutional.separable_conv2d.SeparableConv2D object at 0x7f193e6a9ab0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f193e6a9090>, because it is not built.
# W0327 23:19:39.464111 139749666430976 save_impl.py:66] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f193e6a9090>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.src.layers.core.lambda_layer.Lambda object at 0x7f193e6ab940>, because it is not built.
# W0327 23:19:39.464153 139749666430976 save_impl.py:66] Skipping full serialization of Keras layer <keras.src.layers.core.lambda_layer.Lambda object at 0x7f193e6ab940>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.src.layers.convolutional.separable_conv2d.SeparableConv2D object at 0x7f193e6ab130>, because it is not built.
# W0327 23:19:39.464193 139749666430976 save_impl.py:66] Skipping full serialization of Keras layer <keras.src.layers.convolutional.separable_conv2d.SeparableConv2D object at 0x7f193e6ab130>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f193e6a8d60>, because it is not built.
# W0327 23:19:39.464233 139749666430976 save_impl.py:66] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f193e6a8d60>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.src.layers.core.lambda_layer.Lambda object at 0x7f193e6a8040>, because it is not built.
# W0327 23:19:39.464272 139749666430976 save_impl.py:66] Skipping full serialization of Keras layer <keras.src.layers.core.lambda_layer.Lambda object at 0x7f193e6a8040>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f1978527010>, because it is not built.
# W0327 23:19:39.464311 139749666430976 save_impl.py:66] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f1978527010>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.src.layers.core.lambda_layer.Lambda object at 0x7f1978294040>, because it is not built.
# W0327 23:19:39.464350 139749666430976 save_impl.py:66] Skipping full serialization of Keras layer <keras.src.layers.core.lambda_layer.Lambda object at 0x7f1978294040>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f1978122710>, because it is not built.
# W0327 23:19:39.464394 139749666430976 save_impl.py:66] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f1978122710>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.src.layers.core.lambda_layer.Lambda object at 0x7f1978121f30>, because it is not built.
# W0327 23:19:39.464433 139749666430976 save_impl.py:66] Skipping full serialization of Keras layer <keras.src.layers.core.lambda_layer.Lambda object at 0x7f1978121f30>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f1978122380>, because it is not built.
# W0327 23:19:39.464473 139749666430976 save_impl.py:66] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f1978122380>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.src.layers.core.lambda_layer.Lambda object at 0x7f1978122530>, because it is not built.
# W0327 23:19:39.464514 139749666430976 save_impl.py:66] Skipping full serialization of Keras layer <keras.src.layers.core.lambda_layer.Lambda object at 0x7f1978122530>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f1978120670>, because it is not built.
# W0327 23:19:39.464555 139749666430976 save_impl.py:66] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f1978120670>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.src.layers.core.lambda_layer.Lambda object at 0x7f1978121fc0>, because it is not built.
# W0327 23:19:39.464594 139749666430976 save_impl.py:66] Skipping full serialization of Keras layer <keras.src.layers.core.lambda_layer.Lambda object at 0x7f1978121fc0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f19781231f0>, because it is not built.
# W0327 23:19:39.464633 139749666430976 save_impl.py:66] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f19781231f0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.src.layers.core.lambda_layer.Lambda object at 0x7f193e6efc70>, because it is not built.
# W0327 23:19:39.464671 139749666430976 save_impl.py:66] Skipping full serialization of Keras layer <keras.src.layers.core.lambda_layer.Lambda object at 0x7f193e6efc70>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f193e6ec1f0>, because it is not built.
# W0327 23:19:39.464710 139749666430976 save_impl.py:66] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f193e6ec1f0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.src.layers.core.lambda_layer.Lambda object at 0x7f193e6efb50>, because it is not built.
# W0327 23:19:39.464748 139749666430976 save_impl.py:66] Skipping full serialization of Keras layer <keras.src.layers.core.lambda_layer.Lambda object at 0x7f193e6efb50>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f193e6ef520>, because it is not built.
# W0327 23:19:39.464787 139749666430976 save_impl.py:66] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f193e6ef520>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.src.layers.core.lambda_layer.Lambda object at 0x7f193e6ec400>, because it is not built.
# W0327 23:19:39.464826 139749666430976 save_impl.py:66] Skipping full serialization of Keras layer <keras.src.layers.core.lambda_layer.Lambda object at 0x7f193e6ec400>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f197850b2b0>, because it is not built.
# W0327 23:19:39.464865 139749666430976 save_impl.py:66] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f197850b2b0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.src.layers.core.lambda_layer.Lambda object at 0x7f197850aa40>, because it is not built.
# W0327 23:19:39.464903 139749666430976 save_impl.py:66] Skipping full serialization of Keras layer <keras.src.layers.core.lambda_layer.Lambda object at 0x7f197850aa40>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f19782b9ff0>, because it is not built.
# W0327 23:19:39.464942 139749666430976 save_impl.py:66] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f19782b9ff0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.src.layers.core.lambda_layer.Lambda object at 0x7f19782ba7a0>, because it is not built.
# W0327 23:19:39.464981 139749666430976 save_impl.py:66] Skipping full serialization of Keras layer <keras.src.layers.core.lambda_layer.Lambda object at 0x7f19782ba7a0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f19782b82b0>, because it is not built.
# W0327 23:19:39.465020 139749666430976 save_impl.py:66] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f19782b82b0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.src.layers.core.lambda_layer.Lambda object at 0x7f19782b8460>, because it is not built.
# W0327 23:19:39.465061 139749666430976 save_impl.py:66] Skipping full serialization of Keras layer <keras.src.layers.core.lambda_layer.Lambda object at 0x7f19782b8460>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f19782b93f0>, because it is not built.
# W0327 23:19:39.465100 139749666430976 save_impl.py:66] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f19782b93f0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.src.layers.core.lambda_layer.Lambda object at 0x7f19782babc0>, because it is not built.
# W0327 23:19:39.465138 139749666430976 save_impl.py:66] Skipping full serialization of Keras layer <keras.src.layers.core.lambda_layer.Lambda object at 0x7f19782babc0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f19782b9750>, because it is not built.
# W0327 23:19:39.465178 139749666430976 save_impl.py:66] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f19782b9750>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.src.layers.core.lambda_layer.Lambda object at 0x7f19785b86d0>, because it is not built.
# W0327 23:19:39.465218 139749666430976 save_impl.py:66] Skipping full serialization of Keras layer <keras.src.layers.core.lambda_layer.Lambda object at 0x7f19785b86d0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f19785ba860>, because it is not built.
# W0327 23:19:39.465257 139749666430976 save_impl.py:66] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f19785ba860>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.src.layers.core.lambda_layer.Lambda object at 0x7f193e7dec50>, because it is not built.
# W0327 23:19:39.465296 139749666430976 save_impl.py:66] Skipping full serialization of Keras layer <keras.src.layers.core.lambda_layer.Lambda object at 0x7f193e7dec50>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f193e7ddf30>, because it is not built.
# W0327 23:19:39.465335 139749666430976 save_impl.py:66] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f193e7ddf30>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.src.layers.core.lambda_layer.Lambda object at 0x7f193e7dc070>, because it is not built.
# W0327 23:19:39.465374 139749666430976 save_impl.py:66] Skipping full serialization of Keras layer <keras.src.layers.core.lambda_layer.Lambda object at 0x7f193e7dc070>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f193e7de290>, because it is not built.
# W0327 23:19:39.465412 139749666430976 save_impl.py:66] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f193e7de290>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.src.layers.core.lambda_layer.Lambda object at 0x7f193e7de770>, because it is not built.
# W0327 23:19:39.465451 139749666430976 save_impl.py:66] Skipping full serialization of Keras layer <keras.src.layers.core.lambda_layer.Lambda object at 0x7f193e7de770>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f193e7df580>, because it is not built.
# W0327 23:19:39.465489 139749666430976 save_impl.py:66] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f193e7df580>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.src.layers.core.lambda_layer.Lambda object at 0x7f193e7dff70>, because it is not built.
# W0327 23:19:39.465527 139749666430976 save_impl.py:66] Skipping full serialization of Keras layer <keras.src.layers.core.lambda_layer.Lambda object at 0x7f193e7dff70>, because it is not built.
# I0327 23:19:47.073486 139749666430976 save.py:274] Found untraced functions such as WeightSharedConvolutionalBoxPredictor_layer_call_fn, WeightSharedConvolutionalBoxPredictor_layer_call_and_return_conditional_losses, WeightSharedConvolutionalBoxHead_layer_call_fn, WeightSharedConvolutionalBoxHead_layer_call_and_return_conditional_losses, WeightSharedConvolutionalClassHead_layer_call_fn while saving (showing 5 of 173). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Tensorflow/workspace/models/my_ssd_mobnet_v9.2/tfliteexport/saved_model/assets
# I0327 23:19:50.584348 139749666430976 builder_impl.py:804] Assets written to: Tensorflow/workspace/models/my_ssd_mobnet_v9.2/tfliteexport/saved_model/assets
# I0327 23:19:50.764321 139749666430976 fingerprinting_utils.py:48] Writing fingerprint to Tensorflow/workspace/models/my_ssd_mobnet_v9.2/tfliteexport/saved_model/fingerprint.pb

# %%
FROZEN_TFLITE_PATH = os.path.join(paths['TFLITE_PATH'], 'saved_model')
TFLITE_MODEL = os.path.join(paths['TFLITE_PATH'], 'saved_model', 'detect.tflite')

# %%
command = "tflite_convert \
--saved_model_dir={} \
--output_file={} \
--input_shapes=1,300,300,3 \
--input_arrays=normalized_input_image_tensor \
--output_arrays='TFLite_Detection_PostProcess','TFLite_Detection_PostProcess:1','TFLite_Detection_PostProcess:2','TFLite_Detection_PostProcess:3' \
--inference_type=FLOAT \
--allow_custom_ops".format(FROZEN_TFLITE_PATH, TFLITE_MODEL, )

# %%
print(command)
# Out:
# tflite_convert --saved_model_dir=Tensorflow/workspace/models/my_ssd_mobnet_v9.2/tfliteexport/saved_model --output_file=Tensorflow/workspace/models/my_ssd_mobnet_v9.2/tfliteexport/saved_model/detect.tflite --input_shapes=1,300,300,3 --input_arrays=normalized_input_image_tensor --output_arrays='TFLite_Detection_PostProcess','TFLite_Detection_PostProcess:1','TFLite_Detection_PostProcess:2','TFLite_Detection_PostProcess:3' --inference_type=FLOAT --allow_custom_ops

# %%
# !{command}
# Out:
# 2024-03-27 23:19:52.937148: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-03-27 23:19:54.105875: E tensorflow/compiler/xla/stream_executor/cuda/cuda_driver.cc:268] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2024-03-27 23:19:59.301914: W tensorflow/compiler/mlir/lite/python/tf_tfl_flatbuffer_helpers.cc:364] Ignored output_format.
# 2024-03-27 23:19:59.301962: W tensorflow/compiler/mlir/lite/python/tf_tfl_flatbuffer_helpers.cc:367] Ignored drop_control_dependency.

# %% [markdown]
# # 13. Zip and Export Models

# %%
# !tar -czf models.tar.gz {paths['CHECKPOINT_PATH']}

# %%
from google.colab import drive
drive.mount('/content/drive')
